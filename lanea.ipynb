# %%
import pandas as pd
from googlemaps import Client
from itertools import tee
import json

# %%
lanes=pd.read_csv("lanes.csv")
location=pd.read_csv("location.csv")
trips=pd.read_csv("trips (1).csv")

# %%
lanes
# Out:
#   name  source__001  source__002  destination__001  destination__002
# 0    a    19.362075    73.157823         12.989481         77.805623
# 1    b    17.263056    78.378938         22.599906         88.229947
# 2    c    28.306872    76.883930         12.989481         77.805623

# %%
location
# Out:
#                          trip_id                                location  \
# 0       5bb0a44379fb522ef332db04          [12.988706666666667,77.806045]
# 1       5bb0a44379fb522ef332db04  [12.988546666666666,77.80604666666666]
# 2       5bb0a44379fb522ef332db04                                   [0,0]
# 3       5bb0a44379fb522ef332db04  [12.989006666666667,77.80550833333334]
# 4       5bb0a44379fb522ef332db04  [12.989006666666667,77.80550833333334]
# 5       5bb0a44379fb522ef332db04                     [12.98912,77.80538]
# 6       5bb0a44379fb522ef332db04  [12.988096666666667,77.80735833333334]
# 7       5bb0a44379fb522ef332db04          [12.988566666666667,77.806345]
# 8       5bb0a44379fb522ef332db04                                   [0,0]
# 9       5bb0a44379fb522ef332db04  [12.988816666666667,77.80580166666667]
# 10      5bb0a44379fb522ef332db04  [12.988776666666666,77.80534833333333]
# 11      5bb0a44379fb522ef332db04                                   [0,0]
# ...

# %%
trips
# Out:
#                       trip_id  device lane                start_time  \
# 0    5bb0a44379fb522ef332db04     567    a  2018-09-30T10:24:03.869Z
# 1    5bb0916579fb522ef332d5eb     129    b  2018-09-30T09:03:33.993Z
# 2    5bb07ff179fb522ef332d1ae     512    c  2018-09-30T07:49:05.188Z
# 3    5bafef9ba97c177c19d315ec     547    b  2018-09-29T21:33:15.085Z
# 4    5bafdf23a97c177c19d31178     317    a  2018-09-29T20:22:59.169Z
# 5    5bafd2d6f902bf63b36e6222     444    c  2018-09-29T19:30:30.834Z
# 6    5baf5e0387e11b5b1ac692c9     574    b  2018-09-29T11:12:03.610Z
# 7    5baf350787e11b5b1ac6899c     464    c  2018-09-29T08:17:11.209Z
# 8    5baea84934046d43939d3985     548    b  2018-09-28T22:16:41.813Z
# 9    5bae7c65a55029143aedf00b     375    a  2018-09-28T19:09:25.756Z
# 10   5bae2391a2d54975170c3d79     502    b  2018-09-28T12:50:25.272Z
# 11   5badee25a2d54975170c2de7     535    a  2018-09-28T09:02:29.119Z
# 12   5baddaf88ec4635094c5825c     530    c  2018-09-28T07:40:40.492Z
# ...

# %%
#Listing all trip_id that travel in lane a
#Listing all trip_id that travel in lane b
#Listing all trip_id that travel in lane c

tripa=trips[trips['lane']=='a']
tripa
# Out:
#                       trip_id  device lane                start_time  \
# 0    5bb0a44379fb522ef332db04     567    a  2018-09-30T10:24:03.869Z
# 4    5bafdf23a97c177c19d31178     317    a  2018-09-29T20:22:59.169Z
# 9    5bae7c65a55029143aedf00b     375    a  2018-09-28T19:09:25.756Z
# 11   5badee25a2d54975170c2de7     535    a  2018-09-28T09:02:29.119Z
# 14   5bad1e45c3c4c701a1ce1ea7     564    a  2018-09-27T18:15:33.562Z
# 19   5babd098d3f038761b21ba0e     317    a  2018-09-26T18:31:52.126Z
# 22   5bab589a952f007b686a0f16     159    a  2018-09-26T09:59:54.859Z
# 25   5baa7cf0a25fba41a1fad333     572    a  2018-09-25T18:22:40.410Z
# 27   5baa130f99f9a4472a87bf2c     592    a  2018-09-25T10:50:55.066Z
# 34   5ba68d26b8cc3b01e05bf78b     540    a  2018-09-22T18:42:46.184Z
# 36   5ba604cb22c61434e4568600     166    a  2018-09-22T09:00:59.567Z
# 39   5ba5568a845ceb3b95a0b010     528    a  2018-09-21T20:37:30.077Z
# 47   5ba358934e20262d8398282b     317    a  2018-09-20T08:21:39.517Z
# ...

# %%
from datetime import datetime

timelist=[]
dt=pd.read_csv("time-distancelineA.csv")
distancelist=[]
for i in tripa['trip_id']:
    cur_trip=location[location['trip_id']==i]
    
    try:
        trip_start_time=cur_trip["time"].iloc[0]
        trip_start_latlong=cur_trip["location"].iloc[0]
        trip_start_latlong=trip_start_latlong[1:-1].split(",")
        trip_start_latlong=(trip_start_latlong[0],trip_start_latlong[1])
        for j in cur_trip['time']:
            trip_end_time=j
       
            datetimeObj1 = datetime.strptime(trip_end_time, '%Y-%m-%dT%H:%M:%S.%fZ')
            datetimeObj2 = datetime.strptime(trip_start_time, '%Y-%m-%dT%H:%M:%S.%fZ')
            c=datetimeObj2-datetimeObj1

            time=divmod(c.days * 86400 + c.seconds, 60)
            timelist.append(time)
            print(time)
            print(time)
        #print(cur_trip)
        for i in cur_trip['location']:
            trip_end_latlong=i
            trip_end_latlong=trip_end_latlong[1:-1].split(",")
            trip_end_latlong=(trip_end_latlong[0],trip_end_latlong[1])
            print(trip_start_latlong,trip_end_latlong) 
            gmaps = Client(key="AIzaSyDp9Y8Aq77OxlJn7JHvIumb_ccw2wAdw8g")
            result = gmaps.distance_matrix(trip_start_latlong, trip_end_latlong , mode='driving')["rows"][0]["elements"][0]
            try:
                result=result['distance']['value']
                
            except:
                result=0
            print(result)    
            distancelist.append(result)    
    
    except:
        trip_start_time='' 
    break    
       

   
    
        
print(len(distancelist))
print(len(timelist))

dt['distance']=distancelist
dt['time']=timelist
# Out:
# (0, 0)
# (0, 0)
# (1, 0)
# (1, 0)
# (2, 1)
# (2, 1)
# (30, 2)
# (30, 2)
# (31, 2)
# (31, 2)
# (32, 2)
# (32, 2)
# (60, 4)
# (60, 4)
# (61, 4)
# (61, 4)
# (62, 5)
# (62, 5)
# (90, 8)
# (90, 8)
# (91, 8)
# (91, 8)
# (92, 7)
# (92, 7)
# (120, 10)
# (120, 10)
# (121, 10)
# (121, 10)
# (122, 10)
# (122, 10)
# (150, 11)
# (150, 11)
# (151, 11)
# (151, 11)
# (152, 11)
# (152, 11)
# (180, 13)
# (180, 13)
# (181, 13)
# (181, 13)
# (182, 13)
# (182, 13)
# (210, 17)
# (210, 17)
# (211, 17)
# (211, 17)
# (212, 17)
# (212, 17)
# (240, 19)
# (240, 19)
# (241, 19)
# (241, 19)
# (242, 19)
# (242, 19)
# (270, 20)
# (270, 20)
# (271, 20)
# (271, 20)
# (272, 20)
# (272, 20)
# (300, 23)
# (300, 23)
# (301, 23)
# (301, 23)
# (302, 23)
# (302, 23)
# (330, 24)
# (330, 24)
# (331, 24)
# (331, 24)
# (332, 24)
# (332, 24)
# (360, 28)
# (360, 28)
# (361, 28)
# (361, 28)
# (391, 29)
# (391, 29)
# (362, 26)
# (362, 26)
# (392, 29)
# (392, 29)
# (420, 32)
# (420, 32)
# (421, 32)
# (421, 32)
# (422, 32)
# ...

# %%
dt
# Out:
#            time  distance
# 0        (0, 0)         0
# 1        (1, 0)        13
# 2        (2, 1)         0
# 3       (30, 2)        14
# 4       (31, 2)        14
# 5       (32, 2)        14
# 6       (60, 4)       247
# 7       (61, 4)        10
# 8       (62, 5)         0
# 9       (90, 8)         8
# 10      (91, 8)        44
# 11      (92, 7)         0
# 12    (120, 10)        38
# 13    (121, 10)        38
# 14    (122, 10)        43
# 15    (150, 11)        33
# 16    (151, 11)        33
# 17    (152, 11)        42
# 18    (180, 13)        41
# 19    (181, 13)        41
# 20    (182, 13)        42
# 21    (210, 17)        35
# 22    (211, 17)        35
# 23    (212, 17)        42
# 24    (240, 19)        16
# 25    (241, 19)        16
# 26    (242, 19)        13
# 27    (270, 20)        36
# 28    (271, 20)        44
# 29    (272, 20)        48
# ..          ...       ...
# 152  (1531, 56)    878934
# 153  (1532, 56)    878961
# 154  (1533, 56)    878974
# ...

# %%
#applying Linear regression
import numpy as np
from sklearn.linear_model import LinearRegression
eta_model = LinearRegression()
x=dt[['distance']]
a=[]
b=[]
for y in dt['time']:
    a.append(y)
for y in range(len(a)):
    b.append(a[y][0])
    
    

eta_model.fit(x[:150],b[:150])
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None,
#          normalize=False)

# %%
#Testing predection Accuracy 
a=np.array([878934])
b=np.reshape(a, (-1, 1))
laos_life_exp = eta_model.predict(b)
print("ETA in hrs",laos_life_exp[0]/60)
# Out:
# ETA in hrs 26.148986037366043

# %% [markdown]
# # predecting avg speed of truck 33kmph

# %%
#Could not train with all trip id due to low Internet :)
